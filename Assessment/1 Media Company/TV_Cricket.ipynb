# %%
import numpy as np
import pandas as pd

# %%
show_master = pd.read_csv(r"D:\PG-DAI\MachineLearning\Assessment\1\mediacompany.csv")

# %%
show_master.tail()
# Out:
#          Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 75  5/15/2017      313945   1808684         2226788     1398052759
# 76  5/16/2017      185689   1814227         2199844     1311961223
# 77  5/17/2017      142260   1755803         2225752     1248266254
# 78  5/18/2017      135871   1749654         2302789     1284859759
# 79  5/19/2017      108961   1746735         2279036     1246026846
#
#     Cricket_match_india  Character_A  Unnamed: 7
# 75                    1            0         NaN
# 76                    1            0         NaN
# 77                    1            0         NaN
# 78                    1            0         NaN
# 79                    1            0         NaN

# %%
show_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 80 non-null     object
#  1   Views_show           80 non-null     int64
#  2   Visitors             80 non-null     int64
#  3   Views_platform       80 non-null     int64
#  4   Ad_impression        80 non-null     int64
#  5   Cricket_match_india  80 non-null     int64
#  6   Character_A          80 non-null     int64
#  7   Unnamed: 7           0 non-null      float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 5.1+ KB

# %%
show_master.isnull().value_counts()
# Out:
# Date   Views_show  Visitors  Views_platform  Ad_impression  Cricket_match_india  Character_A  Unnamed: 7
# False  False       False     False           False          False                False        True          80
# dtype: int64

# %%
show_master = show_master.iloc[:, :-1]
#removing the nan coloumn

# %%
# x_train = show_master.drop('Views_show', axis=1, inplace=True)
show_master.columns

# type(x_train)
# Out:
# Index(['Date', 'Views_show', 'Visitors', 'Views_platform', 'Ad_impression',
#        'Cricket_match_india', 'Character_A'],
#       dtype='object')

# %%
# y_train = show_master['Views_show']
# y_train

# %%
show_master['Date'] = pd.to_datetime(show_master['Date'].str.strip(), format='%m/%d/%Y')

# %%
show_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 80 non-null     datetime64[ns]
#  1   Views_show           80 non-null     int64
#  2   Visitors             80 non-null     int64
#  3   Views_platform       80 non-null     int64
#  4   Ad_impression        80 non-null     int64
#  5   Cricket_match_india  80 non-null     int64
#  6   Character_A          80 non-null     int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 4.5 KB

# %%
show_master
# Out:
#          Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0  2017-03-01      183738   1260228         1706478     1060860448
# 1  2017-03-02      193763   1270561         1690727     1031846645
# 2  2017-03-03      210479   1248183         1726157     1010867575
# 3  2017-03-04      240061   1492913         1855353     1079194579
# 4  2017-03-05      446314   1594712         2041418     1357736987
# ..        ...         ...       ...             ...            ...
# 75 2017-05-15      313945   1808684         2226788     1398052759
# 76 2017-05-16      185689   1814227         2199844     1311961223
# 77 2017-05-17      142260   1755803         2225752     1248266254
# 78 2017-05-18      135871   1749654         2302789     1284859759
# 79 2017-05-19      108961   1746735         2279036     1246026846
#
#     Cricket_match_india  Character_A
# 0                     0            0
# 1                     0            0
# 2                     0            0
# ...

# %%
sns.boxplot(x = show_master['Date'], y = show_master['Views_show'], data = show_master, hue = 'Character_A')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Views_show'>

# %%
#Converting dates to number of weekday
show_master['Day']= show_master['Date'].dt.dayofweek

# %%
show_master
# Out:
#          Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0  2017-03-01      183738   1260228         1706478     1060860448
# 1  2017-03-02      193763   1270561         1690727     1031846645
# 2  2017-03-03      210479   1248183         1726157     1010867575
# 3  2017-03-04      240061   1492913         1855353     1079194579
# 4  2017-03-05      446314   1594712         2041418     1357736987
# ..        ...         ...       ...             ...            ...
# 75 2017-05-15      313945   1808684         2226788     1398052759
# 76 2017-05-16      185689   1814227         2199844     1311961223
# 77 2017-05-17      142260   1755803         2225752     1248266254
# 78 2017-05-18      135871   1749654         2302789     1284859759
# 79 2017-05-19      108961   1746735         2279036     1246026846
#
#     Cricket_match_india  Character_A  Day
# 0                     0            0    2
# 1                     0            0    3
# ...

# %%
sns.boxplot(x = show_master['Day'], y = show_master['Views_show'], data = show_master, hue = 'Character_A')
#0 is monday #6 is sunday
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Views_show'>

# %%
sns.boxplot(x = show_master['Day'], y = show_master['Views_show'], data = show_master, hue = 'Cricket_match_india')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Views_show'>

# %%
x= show_master['Date']
y=show_master['Views_show']
fig,ax = plt.subplots(figsize=(20,10))
# ax.plot(show_master['Date'],show_master['Ad_impression'],marker='x',)
# ax.plot(show_master['Date'],show_master['Views_show'],marker='o',)
plt.plot(x, y, label = "Show Views")
plt.plot(x, show_master['Views_platform'], label = "Platform Views")
plt.plot(x, show_master['Visitors'], label = "Visitors")
plt.plot(x, show_master['Cricket_match_india']*3000000, label = "Cricket")
plt.plot(x, show_master['Character_A']*3000000, label = "Character")

plt.legend()
# plt.plot(y, x, label = "line 2")

# %%
show_master.columns
# Out:
# Index(['Date', 'Views_show', 'Visitors', 'Views_platform', 'Ad_impression',
#        'Cricket_match_india', 'Character_A', 'Day'],
#       dtype='object')

# %%
import seaborn as s
sns.set()
sns.lineplot(x='Date', y="Views_show", hue="Character_A", markers=True, data=show_master)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Views_show'>

# %%
x = show_master.iloc[:, [2,3,4,5,6,7]]

# %%
show_master
# Out:
#          Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0  2017-03-01      183738   1260228         1706478     1060860448
# 1  2017-03-02      193763   1270561         1690727     1031846645
# 2  2017-03-03      210479   1248183         1726157     1010867575
# 3  2017-03-04      240061   1492913         1855353     1079194579
# 4  2017-03-05      446314   1594712         2041418     1357736987
# ..        ...         ...       ...             ...            ...
# 75 2017-05-15      313945   1808684         2226788     1398052759
# 76 2017-05-16      185689   1814227         2199844     1311961223
# 77 2017-05-17      142260   1755803         2225752     1248266254
# 78 2017-05-18      135871   1749654         2302789     1284859759
# 79 2017-05-19      108961   1746735         2279036     1246026846
#
#     Cricket_match_india  Character_A  Day
# 0                     0            0    2
# 1                     0            0    3
# ...

# %%
master_train
# Out:
#     Visitors  Views_platform  Ad_impression  Cricket_match_india  Character_A  \
# 0    1260228         1706478     1060860448                    0            0
# 1    1270561         1690727     1031846645                    0            0
# 2    1248183         1726157     1010867575                    0            0
# 3    1492913         1855353     1079194579                    1            0
# 4    1594712         2041418     1357736987                    0            0
# ..       ...             ...            ...                  ...          ...
# 75   1808684         2226788     1398052759                    1            0
# 76   1814227         2199844     1311961223                    1            0
# 77   1755803         2225752     1248266254                    1            0
# 78   1749654         2302789     1284859759                    1            0
# 79   1746735         2279036     1246026846                    1            0
#
#     Day
# 0     2
# 1     3
# ...

# %%
y = show_master['Views_show']

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV
elasticCV = ElasticNetCV(alphas = None, cv = 5)
elasticCV.fit(x,y)
print(elasticCV.alpha_)
print(elasticCV.l1_ratio)
# Out:
# 8245460224749.216
# 0.5

# %%
import statsmodels.api as sm

model = sm.OLS(y, x).fit()
model.summary()

# %%
show_master.head(2)
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
#
#    Cricket_match_india  Character_A  Day
# 0                    0            0    2
# 1                    0            0    3

# %% [markdown]
# Cricket_match_india	3627.6793	4.02e+04	0.090	0.928	-7.66e+04	8.38e+04
#
#
# Dropping Cricket_match_india

# %%
x = show_master.iloc[:, [2,3,4,6,7]]

# %%
x = show_master.iloc[:, [2,3,4,6,7]]
import statsmodels.api as sm

model = sm.OLS(y, x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             Views_show   R-squared (uncentered):                   0.913
# Model:                            OLS   Adj. R-squared (uncentered):              0.907
# Method:                 Least Squares   F-statistic:                              157.5
# Date:                Sun, 19 Dec 2021   Prob (F-statistic):                    2.68e-38
# Time:                        18:09:55   Log-Likelihood:                         -1032.0
# No. Observations:                  80   AIC:                                      2074.
# Df Residuals:                      75   BIC:                                      2086.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Visitors	0.0574	0.176	0.326	0.745	-0.293	0.408
#
# Dropping Visitors

# %%
x = show_master.iloc[:, [3,4,6,7]]
import statsmodels.api as sm

model = sm.OLS(y, x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             Views_show   R-squared (uncentered):                   0.913
# Model:                            OLS   Adj. R-squared (uncentered):              0.908
# Method:                 Least Squares   F-statistic:                              199.1
# Date:                Sun, 19 Dec 2021   Prob (F-statistic):                    1.88e-39
# Time:                        18:10:40   Log-Likelihood:                         -1032.0
# No. Observations:                  80   AIC:                                      2072.
# Df Residuals:                      76   BIC:                                      2082.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Character_A	1.074e+04	2.71e+04	0.396	0.693	-4.33e+04	6.47e+04
#
# Dropping Character_A

# %%
x = show_master.iloc[:, [3,4,7]]
import statsmodels.api as sm

model = sm.OLS(y, x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             Views_show   R-squared (uncentered):                   0.913
# Model:                            OLS   Adj. R-squared (uncentered):              0.909
# Method:                 Least Squares   F-statistic:                              268.4
# Date:                Sun, 19 Dec 2021   Prob (F-statistic):                    1.14e-40
# Time:                        18:11:32   Log-Likelihood:                         -1032.1
# No. Observations:                  80   AIC:                                      2070.
# Df Residuals:                      77   BIC:                                      2077.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
